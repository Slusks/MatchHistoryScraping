# %%
import pandas as pd
from pathlib import Path

# %%
file = Path(r"F:\LeagueStats\scraping\MatchHistoryScraping\match_database.csv")

# %%
df = pd.read_csv(file)
test_file = Path(r"F:\LeagueStats\scraping\MatchHistoryScraping\testing_dups.csv")
no_dup = df.drop_duplicates()
no_dup.to_csv(test_file, index = False, header=True)
testDF = pd.read_csv(test_file)

# %%
testDF.head()
# Out:
#      KDA  Largest Killing Spree  Largest Multi Kill First Blood  \
# 0  4/4/1                      3                 2.0           ○
# 1  0/7/5                      0                 0.0           ○
# 2  0/2/5                      0                 0.0           ○
# 3  1/4/2                      1                 1.0           ○
# 4  0/4/3                      0                 0.0           ○
#
#   Total Damage to Champions Physical Damage to Champions  \
# 0                     24.4k                        18.9k
# 1                      3.0k                         2.0k
# 2                     21.7k                         0.6k
# 3                     18.8k                        16.1k
# 4                      5.0k                         0.5k
#
#   Magic Damage to Champions True Damage to Champions Total Damage Dealt  \
# 0                      3.5k                     2.0k             221.8k
# 1                      0.6k                     0.4k             109.4k
# ...

# %%
nochamp = testDF

# %%
del nochamp['champion']

# %%
nochamp.head()
# Out:
#      KDA  Largest Killing Spree  Largest Multi Kill First Blood  \
# 0  4/4/1                      3                 2.0           ○
# 1  0/7/5                      0                 0.0           ○
# 2  0/2/5                      0                 0.0           ○
# 3  1/4/2                      1                 1.0           ○
# 4  0/4/3                      0                 0.0           ○
#
#   Total Damage to Champions Physical Damage to Champions  \
# 0                     24.4k                        18.9k
# 1                      3.0k                         2.0k
# 2                     21.7k                         0.6k
# 3                     18.8k                        16.1k
# 4                      5.0k                         0.5k
#
#   Magic Damage to Champions True Damage to Champions Total Damage Dealt  \
# 0                      3.5k                     2.0k             221.8k
# 1                      0.6k                     0.4k             109.4k
# ...

# %%
nochamp_dup = nochamp[nochamp.duplicated()]

# %%
print (nochamp_dup)
# Out:
#         KDA  Largest Killing Spree  Largest Multi Kill First Blood  \
# 480   2/6/4                      2                 1.0           ○
# 481   4/3/4                      3                 1.0           ○
# 482  5/0/10                      5                 3.0           ○
# 483  4/3/10                      2                 2.0           ○
# 484  3/3/12                      2                 1.0           ○
# 485   3/3/2                      2                 1.0           ●
# 486   1/4/4                      1                 1.0           ○
# 487   5/4/3                      3                 1.0           ○
# 488   2/6/5                      2                 1.0           ○
# 489   0/6/6                      0                 0.0           ○
# 490   1/3/4                      1                 1.0           ○
# 491  11/3/7                      9                 3.0           ○
# 492  3/1/14                      3                 2.0           ○
# ...

# %%
nochamp_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 480 to 538
# Data columns (total 31 columns):
# KDA                                        39 non-null object
# Largest Killing Spree                      39 non-null int64
# Largest Multi Kill                         39 non-null float64
# First Blood                                39 non-null object
# Total Damage to Champions                  39 non-null object
# Physical Damage to Champions               39 non-null object
# Magic Damage to Champions                  39 non-null object
# True Damage to Champions                   39 non-null object
# Total Damage Dealt                         39 non-null object
# Physical Damage Dealt                      39 non-null object
# Magic Damage Dealt                         39 non-null object
# True Damage Dealt                          39 non-null object
# Largest Critical Strike                    39 non-null object
# ...

# %%
testDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167839 entries, 0 to 167838
# Data columns (total 31 columns):
# KDA                                        167839 non-null object
# Largest Killing Spree                      167839 non-null int64
# Largest Multi Kill                         167839 non-null float64
# First Blood                                167839 non-null object
# Total Damage to Champions                  167839 non-null object
# Physical Damage to Champions               167839 non-null object
# Magic Damage to Champions                  167839 non-null object
# True Damage to Champions                   167839 non-null object
# Total Damage Dealt                         167839 non-null object
# Physical Damage Dealt                      167839 non-null object
# Magic Damage Dealt                         167839 non-null object
# True Damage Dealt                          167839 non-null object
# ...

# %%
testDF.columns
# Out:
# Index(['KDA', 'Largest Killing Spree', 'Largest Multi Kill', 'First Blood',
#        'Total Damage to Champions', 'Physical Damage to Champions',
#        'Magic Damage to Champions', 'True Damage to Champions',
#        'Total Damage Dealt', 'Physical Damage Dealt', 'Magic Damage Dealt',
#        'True Damage Dealt', 'Largest Critical Strike',
#        'Total Damage to Objectives', 'Total Damage to Turrets',
#        'Damage Healed', 'Damage Taken', 'Physical Damage Taken',
#        'Magic Damage Taken', 'True Damage Taken', 'Wards Placed',
#        'Wards Destroyed', 'Stealth Wards Purchased', 'Control Wards Purchased',
#        'Gold Earned', 'Gold Spent', 'Minions Killed', 'Neutral Minions Killed',
#        'Neutral Minions Killed in Team's Jungle',
#        'Neutral Minions Killed in Enemy Jungle', 'url'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['KDA', 'Largest Killing Spree', 'Largest Multi Kill', 'First Blood',
#        'Total Damage to Champions', 'Physical Damage to Champions',
#        'Magic Damage to Champions', 'True Damage to Champions',
#        'Total Damage Dealt', 'Physical Damage Dealt', 'Magic Damage Dealt',
#        'True Damage Dealt', 'Largest Critical Strike',
#        'Total Damage to Objectives', 'Total Damage to Turrets',
#        'Damage Healed', 'Damage Taken', 'Physical Damage Taken',
#        'Magic Damage Taken', 'True Damage Taken', 'Wards Placed',
#        'Wards Destroyed', 'Stealth Wards Purchased', 'Control Wards Purchased',
#        'Gold Earned', 'Gold Spent', 'Minions Killed', 'Neutral Minions Killed',
#        'Neutral Minions Killed in Team's Jungle',
#        'Neutral Minions Killed in Enemy Jungle', 'url', 'champion'],
#       dtype='object')

# %%
no_champ_header = ["KDA", "Largest Killing Spree", "Largest Multi Kill", "First Blood",
       "Total Damage to Champions", "Physical Damage to Champions",
       "Magic Damage to Champions", "True Damage to Champions",
       "Total Damage Dealt", "Physical Damage Dealt", "Magic Damage Dealt",
       "True Damage Dealt", "Largest Critical Strike",
       "Total Damage to Objectives", "Total Damage to Turrets",
       "Damage Healed", "Damage Taken", "Physical Damage Taken",
       "Magic Damage Taken", "True Damage Taken", "Wards Placed",
       "Wards Destroyed", "Stealth Wards Purchased", "Control Wards Purchased",
       "Gold Earned", "Gold Spent", "Minions Killed", "Neutral Minions Killed",
       "Neutral Minions Killed in Team's Jungle",
       "Neutral Minions Killed in Enemy Jungle", "url"]

# %%
df = pd.read_csv(file)
test_file = Path(r"F:\LeagueStats\scraping\MatchHistoryScraping\testing_dups.csv")
no_dup = df.drop_duplicates()
no_dup.to_csv(test_file, index = False, header=True)
testDF = pd.read_csv(test_file)

# %%
testDF.head()
# Out:
#      KDA  Largest Killing Spree  Largest Multi Kill First Blood  \
# 0  4/4/1                      3                 2.0           ○
# 1  0/7/5                      0                 0.0           ○
# 2  0/2/5                      0                 0.0           ○
# 3  1/4/2                      1                 1.0           ○
# 4  0/4/3                      0                 0.0           ○
#
#   Total Damage to Champions Physical Damage to Champions  \
# 0                     24.4k                        18.9k
# 1                      3.0k                         2.0k
# 2                     21.7k                         0.6k
# 3                     18.8k                        16.1k
# 4                      5.0k                         0.5k
#
#   Magic Damage to Champions True Damage to Champions Total Damage Dealt  \
# 0                      3.5k                     2.0k             221.8k
# 1                      0.6k                     0.4k             109.4k
# ...

# %%
testDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167839 entries, 0 to 167838
# Data columns (total 32 columns):
# KDA                                        167839 non-null object
# Largest Killing Spree                      167839 non-null int64
# Largest Multi Kill                         167839 non-null float64
# First Blood                                167839 non-null object
# Total Damage to Champions                  167839 non-null object
# Physical Damage to Champions               167839 non-null object
# Magic Damage to Champions                  167839 non-null object
# True Damage to Champions                   167839 non-null object
# Total Damage Dealt                         167839 non-null object
# Physical Damage Dealt                      167839 non-null object
# Magic Damage Dealt                         167839 non-null object
# True Damage Dealt                          167839 non-null object
# ...

# %%
#this should drop the duplicate rows even if for some of them there is a champion and some of them there is not.
result_df = df.drop_duplicates(subset=no_champ_header, keep='first')

# %%
result_df.head()
# Out:
#      KDA  Largest Killing Spree  Largest Multi Kill First Blood  \
# 0  4/4/1                      3                 2.0           ○
# 1  0/7/5                      0                 0.0           ○
# 2  0/2/5                      0                 0.0           ○
# 3  1/4/2                      1                 1.0           ○
# 4  0/4/3                      0                 0.0           ○
#
#   Total Damage to Champions Physical Damage to Champions  \
# 0                     24.4k                        18.9k
# 1                      3.0k                         2.0k
# 2                     21.7k                         0.6k
# 3                     18.8k                        16.1k
# 4                      5.0k                         0.5k
#
#   Magic Damage to Champions True Damage to Champions Total Damage Dealt  \
# 0                      3.5k                     2.0k             221.8k
# 1                      0.6k                     0.4k             109.4k
# ...

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167800 entries, 0 to 168099
# Data columns (total 32 columns):
# KDA                                        167800 non-null object
# Largest Killing Spree                      167800 non-null int64
# Largest Multi Kill                         167800 non-null float64
# First Blood                                167800 non-null object
# Total Damage to Champions                  167800 non-null object
# Physical Damage to Champions               167800 non-null object
# Magic Damage to Champions                  167800 non-null object
# True Damage to Champions                   167800 non-null object
# Total Damage Dealt                         167800 non-null object
# Physical Damage Dealt                      167800 non-null object
# Magic Damage Dealt                         167800 non-null object
# True Damage Dealt                          167800 non-null object
# ...

# %%
df_no_dups = result_df

# %%
bad = df_no_dups[df_no_dups['champion']=='False']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-8d076b83b705> in <module>
# ----> 1 bad = df_no_dups[df_no_dups['champion']=='False'].tolist()
#
# c:\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'tolist'

# %%
type(bad)
# Out:
# pandas.core.frame.DataFrame

# %%
bad.head()
# Out:
#          KDA  Largest Killing Spree  Largest Multi Kill First Blood  \
# 4400   0/5/2                      0                 0.1           ○
# 4401   3/3/8                      3                 1.0           ○
# 4402   5/3/2                      3                 2.0           ○
# 4403   5/3/4                      3                 2.0           ○
# 4404  0/6/10                      0                 0.0           ○
#
#      Total Damage to Champions Physical Damage to Champions  \
# 4400                      8.1k                       8.1k.1
# 4401                     11.1k                         0.6k
# 4402                     20.3k                         0.6k
# 4403                     22.5k                        17.0k
# 4404                      2.9k                         0.6k
#
#      Magic Damage to Champions True Damage to Champions Total Damage Dealt  \
# 4400                      0.0k                   0.0k.1             324.7k
# ...

# %%
bad.info() # the number of columns with a False champion
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10720 entries, 4400 to 168069
# Data columns (total 32 columns):
# KDA                                        10720 non-null object
# Largest Killing Spree                      10720 non-null int64
# Largest Multi Kill                         10720 non-null float64
# First Blood                                10720 non-null object
# Total Damage to Champions                  10720 non-null object
# Physical Damage to Champions               10720 non-null object
# Magic Damage to Champions                  10720 non-null object
# True Damage to Champions                   10720 non-null object
# Total Damage Dealt                         10720 non-null object
# Physical Damage Dealt                      10720 non-null object
# Magic Damage Dealt                         10720 non-null object
# True Damage Dealt                          10720 non-null object
# Largest Critical Strike                    10720 non-null object
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [KDA, Largest Killing Spree, Largest Multi Kill, First Blood, Total Damage to Champions, Physical Damage to Champions, Magic Damage to Champions, True Damage to Champions, Total Damage Dealt, Physical Damage Dealt, Magic Damage Dealt, True Damage Dealt, Largest Critical Strike, Total Damage to Objectives, Total Damage to Turrets, Damage Healed, Damage Taken, Physical Damage Taken, Magic Damage Taken, True Damage Taken, Wards Placed, Wards Destroyed, Stealth Wards Purchased, Control Wards Purchased, Gold Earned, Gold Spent, Minions Killed, Neutral Minions Killed, Neutral Minions Killed in Team's Jungle, Neutral Minions Killed in Enemy Jungle, url, champion]
# Index: []
#
# [0 rows x 32 columns]

# %%
df_no_dups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167800 entries, 0 to 168099
# Data columns (total 32 columns):
# KDA                                        167800 non-null object
# Largest Killing Spree                      167800 non-null int64
# Largest Multi Kill                         167800 non-null float64
# First Blood                                167800 non-null object
# Total Damage to Champions                  167800 non-null object
# Physical Damage to Champions               167800 non-null object
# Magic Damage to Champions                  167800 non-null object
# True Damage to Champions                   167800 non-null object
# Total Damage Dealt                         167800 non-null object
# Physical Damage Dealt                      167800 non-null object
# Magic Damage Dealt                         167800 non-null object
# True Damage Dealt                          167800 non-null object
# ...

# %%
######## This clean file is from the first scrape. We're going to 
######## clean the second smaller scrape and then add it to this and see where we're at.
clean_file = test_file = Path(r"F:\LeagueStats\scraping\cleaning\scraped_file_no_duplicates.csv")
df_no_dups.to_csv(clean_file, index=False, header=True)

# %%
file2 = Path(r"F:\LeagueStats\scraping\MatchHistoryScraping\delinquent_match_database.csv")
df2 = pd.read_csv(file2)
# Out:
# c:\python37\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (21,23,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dup2 = df2[df2.duplicated()]

# %%
dup2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67290 entries, 170 to 98409
# Data columns (total 32 columns):
# KDA                                        67290 non-null object
# Largest Killing Spree                      67290 non-null int64
# Largest Multi Kill                         67290 non-null float64
# First Blood                                67290 non-null object
# Total Damage to Champions                  67290 non-null object
# Physical Damage to Champions               67290 non-null object
# Magic Damage to Champions                  67290 non-null object
# True Damage to Champions                   67290 non-null object
# Total Damage Dealt                         67290 non-null object
# Physical Damage Dealt                      67290 non-null object
# Magic Damage Dealt                         67290 non-null object
# True Damage Dealt                          67290 non-null object
# Largest Critical Strike                    67290 non-null object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98410 entries, 0 to 98409
# Data columns (total 32 columns):
# KDA                                        98410 non-null object
# Largest Killing Spree                      98410 non-null int64
# Largest Multi Kill                         98410 non-null float64
# First Blood                                98410 non-null object
# Total Damage to Champions                  98410 non-null object
# Physical Damage to Champions               98410 non-null object
# Magic Damage to Champions                  98410 non-null object
# True Damage to Champions                   98410 non-null object
# Total Damage Dealt                         98410 non-null object
# Physical Damage Dealt                      98410 non-null object
# Magic Damage Dealt                         98410 non-null object
# True Damage Dealt                          98410 non-null object
# Largest Critical Strike                    98410 non-null object
# ...

# %%
no_dup2 = df2.drop_duplicates()

# %%
no_dup2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31120 entries, 0 to 98389
# Data columns (total 32 columns):
# KDA                                        31120 non-null object
# Largest Killing Spree                      31120 non-null int64
# Largest Multi Kill                         31120 non-null float64
# First Blood                                31120 non-null object
# Total Damage to Champions                  31120 non-null object
# Physical Damage to Champions               31120 non-null object
# Magic Damage to Champions                  31120 non-null object
# True Damage to Champions                   31120 non-null object
# Total Damage Dealt                         31120 non-null object
# Physical Damage Dealt                      31120 non-null object
# Magic Damage Dealt                         31120 non-null object
# True Damage Dealt                          31120 non-null object
# Largest Critical Strike                    31120 non-null object
# ...

# %%
result_df2 = df2.drop_duplicates(subset=no_champ_header, keep='first')
result_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24650 entries, 0 to 98389
# Data columns (total 32 columns):
# KDA                                        24650 non-null object
# Largest Killing Spree                      24650 non-null int64
# Largest Multi Kill                         24650 non-null float64
# First Blood                                24650 non-null object
# Total Damage to Champions                  24650 non-null object
# Physical Damage to Champions               24650 non-null object
# Magic Damage to Champions                  24650 non-null object
# True Damage to Champions                   24650 non-null object
# Total Damage Dealt                         24650 non-null object
# Physical Damage Dealt                      24650 non-null object
# Magic Damage Dealt                         24650 non-null object
# True Damage Dealt                          24650 non-null object
# Largest Critical Strike                    24650 non-null object
# ...

# %%
dupdf2 = df2[df2.duplicated()]

# %%
dupdf2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67290 entries, 170 to 98409
# Data columns (total 32 columns):
# KDA                                        67290 non-null object
# Largest Killing Spree                      67290 non-null int64
# Largest Multi Kill                         67290 non-null float64
# First Blood                                67290 non-null object
# Total Damage to Champions                  67290 non-null object
# Physical Damage to Champions               67290 non-null object
# Magic Damage to Champions                  67290 non-null object
# True Damage to Champions                   67290 non-null object
# Total Damage Dealt                         67290 non-null object
# Physical Damage Dealt                      67290 non-null object
# Magic Damage Dealt                         67290 non-null object
# True Damage Dealt                          67290 non-null object
# Largest Critical Strike                    67290 non-null object
# ...

# %%
series = [('Stranger Things', 3, 'Millie'),
          ('Game of Thrones', 8, 'Emilia'), ('La Casa De Papel', 4, 'Sergio'),
          ('Westworld', 3, 'Evan Rachel'), ('Stranger Things', 3, 'Millie'),
          ('Stranger Things', 3, 'Millie'),
          ('Stranger Things', 3, 'Millie'),('Stranger Things', 3, 'Millie')]

# %%
dfobj = pd.DataFrame(series, columns=['Name', 'Seasons', 'Actor'])
dfobj2 = dfobj[dfobj.duplicated()]

# %%
dfobj2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 4 to 7
# Data columns (total 3 columns):
# Name       4 non-null object
# Seasons    4 non-null int64
# Actor      4 non-null object
# dtypes: int64(1), object(2)
# memory usage: 96.0+ bytes

# %% [markdown]
# dfobj2

# %%
print(dfobj2)
# Out:
#               Name  Seasons   Actor
# 4  Stranger Things        3  Millie
# 5  Stranger Things        3  Millie
# 6  Stranger Things        3  Millie
# 7  Stranger Things        3  Millie

# %%
dfobj.drop_duplicates()
# Out:
#                Name  Seasons        Actor
# 0   Stranger Things        3       Millie
# 1   Game of Thrones        8       Emilia
# 2  La Casa De Papel        4       Sergio
# 3         Westworld        3  Evan Rachel

# %%
df.head()
# Out:
#      KDA  Largest Killing Spree  Largest Multi Kill First Blood  \
# 0  4/4/1                      3                 2.0           ○
# 1  0/7/5                      0                 0.0           ○
# 2  0/2/5                      0                 0.0           ○
# 3  1/4/2                      1                 1.0           ○
# 4  0/4/3                      0                 0.0           ○
#
#   Total Damage to Champions Physical Damage to Champions  \
# 0                     24.4k                        18.9k
# 1                      3.0k                         2.0k
# 2                     21.7k                         0.6k
# 3                     18.8k                        16.1k
# 4                      5.0k                         0.5k
#
#   Magic Damage to Champions True Damage to Champions Total Damage Dealt  \
# 0                      3.5k                     2.0k             221.8k
# 1                      0.6k                     0.4k             109.4k
# ...

# %%
champlist = df.champion.unique().tolist()

# %%
count = 0
for i in champlist:
    print (count)
    print(i)
    count = count + 1
# Out:
# 0
# Jayce
# 1
# JarvanIV
# 2
# Orianna
# 3
# MissFortune
# 4
# Nautilus
# 5
# Aatrox
# 6
# Elise
# 7
# Qiyana
# 8
# Varus
# 9
# TahmKench
# 10
# Renekton
# 11
# RekSai
# 12
# Mordekaiser
# 13
# Xayah
# 14
# Rakan
# 15
# Sejuani
# 16
# Azir
# 17
# Pantheon
# 18
# Quinn
# 19
# Olaf
# 20
# Leona
# 21
# Ryze
# 22
# Velkoz
# 23
# Braum
# 24
# Kennen
# 25
# Ornn
# 26
# Vladimir
# 27
# LeeSin
# 28
# Rumble
# 29
# Thresh
# 30
# Camille
# 31
# Fizz
# 32
# Syndra
# 33
# Senna
# 34
# Irelia
# 35
# Ekko
# 36
# Hecarim
# 37
# Sivir
# 38
# Unnamed: 31
# 39
# Cassiopeia
# 40
# Gragas
# 41
# Lucian
# 42
# Aphelios
# 43
# Zoe
# 44
# Sylas
# 45
# Bard
# 46
# Gangplank
# 47
# Leblanc
# 48
# Yasuo
# 49
# Malphite
# 50
# DrMundo
# 51
# Diana
# 52
# Swain
# 53
# Urgot
# 54
# Ezreal
# 55
# Kaisa
# 56
# Taliyah
# 57
# Zac
# 58
# Karthus
# 59
# Nocturne
# 60
# Nidalee
# 61
# Kassadin
# 62
# Veigar
# 63
# Viktor
# 64
# Ashe
# 65
# Trundle
# 66
# Riven
# 67
# Blitzcrank
# 68
# Zilean
# 69
# Tristana
# 70
# ...

# %%
#index nan 114
#index unnamed: 31 38
